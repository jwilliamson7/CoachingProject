# %% [markdown]
# # Jon Williamson
#
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Reading the data:

# %%
df = pd.read_csv('master_data.csv', index_col=0)
df.fillna(0, inplace=True)
df.head(5)
# Out:
#     Coach Name  Year  Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  \
# 0  Aaron Glenn  2025         53          0          0          0          0
# 1   Abe Gibron  1972         47          0          0          0          0
# 2    Adam Gase  2016         38          0          0          0          0
# 3    Adam Gase  2019         41          1          0          0          0
# 4   Adam Walsh  1945         44          0          8          0         12
#
#    Feature 6  Feature 7  Feature 8  ...  Feature 143  Feature 144  \
# 0          5          4          0  ...    -0.012856    -1.263665
# 1         12          0          0  ...    -0.046360    -1.485902
# 2          5          3          0  ...     0.327322    -0.366410
# 3          5          3          3  ...     1.049007    -1.094508
# 4          0          0          0  ...     0.671841    -0.169465
#
#    Feature 145  Feature 146  Feature 147  Feature 148  Feature 149  \
# 0    -1.187244    -1.102638    -1.624895     0.092283     0.710263
# 1     0.771470    -1.631151     0.145324     0.379353     0.653824
# 2     0.290591    -0.152661    -0.031052    -0.493436    -0.449901
# 3     0.825019    -0.949633     0.344443    -0.329186     0.910021
# 4     1.121897    -0.060971     1.112303     1.146577     0.854598
#
#    Feature 150  Avg 2Y Win Pct  Coach Tenure Class
# 0          0.0        0.000000                  -1
# 1          0.0        0.267857                   1
# 2          0.0        0.500000                   1
# 3          0.0        0.281250                   0
# 4          0.0        0.745455                   0
#
# [5 rows x 154 columns]

# %% [markdown]
# Because the feature names are complex, the stored data labels them only by feature number. The following table maps feature labels to descriptions of each feature.
#
# There are many key takeaways from this set of features. Firstly, the feature set will be sparse for a given data point because no coach has ever been  an offensive coordinator and a defensive coordiantor prior to hiring. Secondly, features 9-140 and 142-150 were normalized using a z-score transformation vs. all teams in the league in that year. This normalization  roughly account for differences in play style over time because performance is always relative to other teams in the league at that time.

# %% [markdown]
# Prior to building the model, it is important to understand the distribution of data. The following code plots the distribution of average 2 year winning percentage for the entire data set.

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 13
plt.rc('axes', titlesize=18) 
plt.rc('axes', labelsize=18) 
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('legend', fontsize=14)
plt.rcParams['font.family'] = "Times New Roman"

# %%
df = df[df['Coach Tenure Class'] != -1]
"""
temp_df = df.iloc[:,2:76].join(df.iloc[:,142:-2])
print(temp_df.head(5))
"""
X = df.iloc[:,2:-2]
y = df.iloc[:,-1]
X.head(5)
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 1         47          0          0          0          0         12
# 2         38          0          0          0          0          5
# 3         41          1          0          0          0          5
# 4         44          0          8          0         12          0
# 5         25          0          0          0          0          0
#
#    Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 141  Feature 142  \
# 1          0          0   0.000000    0.000000  ...     0.428571    -0.956368
# 2          3          0   1.532619    1.348807  ...     0.437500    -0.268496
# 3          3          3   1.532619    1.348807  ...     0.281250    -0.656092
# 4          0          0   0.000000    0.000000  ...     0.400000     0.116123
# 5          0          0   0.000000    0.000000  ...     0.000000     0.000000
#
#    Feature 143  Feature 144  Feature 145  Feature 146  Feature 147  \
# 1    -0.046360    -1.485902     0.771470    -1.631151     0.145324
# 2     0.327322    -0.366410     0.290591    -0.152661    -0.031052
# 3     1.049007    -1.094508     0.825019    -0.949633     0.344443
# 4     0.671841    -0.169465     1.121897    -0.060971     1.112303
# 5     0.000000     0.000000     0.000000     0.000000     0.000000
#
#    Feature 148  Feature 149  Feature 150
# 1     0.379353     0.653824          0.0
# 2    -0.493436    -0.449901          0.0
# 3    -0.329186     0.910021          0.0
# 4     1.146577     0.854598          0.0
# 5     0.000000     0.000000          0.0
#
# [5 rows x 150 columns]

# %%
y.head(5)
# Out:
# 1    1
# 2    1
# 3    0
# 4    0
# 5    0
# Name: Coach Tenure Class, dtype: int64

# %% [markdown]
# The `create_data.py` file segments coach tenure into three classes as such:

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-c3ow{border-color:inherit;text-align:center;vertical-align:top}
# .tg .tg-7btt{border-color:inherit;font-weight:bold;text-align:center;vertical-align:top}
# .tg .tg-fymr{border-color:inherit;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-7btt">Coach Hire Duration (Years)</th>
#     <th class="tg-fymr">Class Label</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-c3ow">1-2</td>
#     <td class="tg-0pky">0</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">3-4</td>
#     <td class="tg-0pky">1</td>
#   </tr>
#   <tr>
#     <td class="tg-c3ow">5+</td>
#     <td class="tg-0pky">2</td>
#   </tr>
# </tbody>
# </table>

# %%
#rcParams['figure.figsize'] = 9, 6.5
raw_coach_class = y.values.T
raw_coach_class_mean = np.mean(raw_coach_class)
plt.hist(raw_coach_class, bins=[-.5,.5,1.5,2.5], color='c', edgecolor='k')
plt.xlim(-0.5,2.5)
plt.xticks(ticks=[0,1,2])
plt.xlabel('Coach Tenure Classification')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The following code prints the correlation matrix for the features. This matrix shows that the data is not highly correlated. The white boxes in the matrix show that that offensive and defensive coordinator metrics have no correlation. This is expected, as no coaches in the set were both an OC and a DC prior to being hired, hence there is no correlation value for those features.

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.matshow(X.corr())
#plt.xticks([0,4,8,12,16,20,24], labels=[1,5,9,13,17,21,25])
#plt.yticks([0,4,8,12,16,20,24], labels=[1,5,9,13,17,21,25])
plt.ylabel('Feature Number')
plt.xlabel('Feature Number', labelpad=-720)

ax = plt.gca()
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.3)

plt.colorbar(cax=cax)
#plt.clim(-1, 1)
plt.show()

# %% [markdown]
# Holding out 20% of data for testing:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.80, shuffle=True, stratify=y, random_state=0)

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score

# %%
def plot_coef(coef_list_dict, title):
    coef_list = [np.abs(l) for l in zip(*coef_list_dict)]
    label_list = [item.split()[-1] for item in X.columns.values]
    label_list.append("")
    plt.boxplot(coef_list)
    plt.xlim(0, len(coef_list) + 1)
    #plt.xticks(np.arange(1, len(label_list) + 1), labels=label_list)
    plt.xticks(np.arange(1, len(label_list) + 1, 5), labels=label_list[::5])
    plt.xlabel('Feature No.')
    plt.ylabel('Feature Weight')
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Model 2: XGBoost Classifier
#
# Necessary Imports:

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# As before, we will implement the model with external cross-validation. Because xgboost does not have internal cross validation to choose hyperparameters, it is necessary to implement hyperparameter cross-validation via `GridSearchCV`.

# %%
"""
xgbr_param_dict = {
    "n_estimators":     [10, 25, 50, 100, 200],
    "learning_rate":    [.01, .05, .1, .2],
    "max_depth":        [2, 4, 6, 8, 10],
    "gamma":            [0, .001, .01, .1],
    "reg_lambda":       [0, .01, .1]
}
"""
xgbr_param_dict = {
    "n_estimators":     [25, 50, 100],
    "learning_rate":    [.05, .1, .2, .3],
    "max_depth":        [2, 3],
    "gamma":            [0, .01, .1],
    "reg_lambda":       [0, .01] 
}

xgbr_best_params_dict = {key: [] for key in xgbr_param_dict.keys()}

xgbr_result_dict = {    'train_score':  [],
                        'test_score':   [],
                        'importance':   []
}
default_xgbr_params = {
    'verbosity':    1,
    'objective':    'multi:softprob',
    'n_jobs':       1
}

num_of_folds=10

skf=StratifiedKFold(n_splits=num_of_folds, shuffle=True)
for train_index, test_index in skf.split(X_train, y_train):
    X_train_, X_test_ = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_, y_test_ = y_train.iloc[train_index].values.ravel(), y_train.iloc[test_index].values.ravel()

    mean_imputer = SimpleImputer()
    X_train__      = mean_imputer.fit_transform(X_train_)
    X_test__       = mean_imputer.transform(X_test_)

    model = GridSearchCV(XGBClassifier(**default_xgbr_params), param_grid=xgbr_param_dict, scoring='roc_auc_ovr', n_jobs=-1, cv=5, verbose=1).fit(X_train__, y_train_)
    for key, value in model.best_params_.items():
        xgbr_best_params_dict[key].append(value)
    best_model = model.best_estimator_
    xgbr_result_dict['importance'].append(best_model.feature_importances_)

    tr_pred = best_model.predict_proba(X_train__)
    te_pred  = best_model.predict_proba(X_test__)

    xgbr_result_dict['test_score'].append(roc_auc_score(y_test_, te_pred, average='macro', multi_class='ovr'))
    xgbr_result_dict['train_score'].append(roc_auc_score(y_train_, tr_pred, average='macro', multi_class='ovr'))
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   16.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   13.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   13.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   13.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   13.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   14.2s finished
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 689 out of 720 | elapsed:   14.3s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   15.0s finished
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   16.1s finished
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   15.4s finished
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:   14.3s finished

# %%
print('Average Train AUROC: {:.3f}\nAverage Test AUROC: {:.3f}'.format(np.mean(xgbr_result_dict['train_score']), np.mean(xgbr_result_dict['test_score'])))
# Out:
# Average Train AUROC: 0.931
# Average Test AUROC: 0.649

# %%
xgbr_best_params_dict
# Out:
# {'n_estimators': [25, 25, 25, 25, 25, 50, 50, 50, 50, 25],
#  'learning_rate': [0.3, 0.05, 0.3, 0.3, 0.2, 0.1, 0.05, 0.1, 0.2, 0.3],
#  'max_depth': [3, 3, 3, 2, 2, 3, 2, 3, 2, 3],
#  'gamma': [0.1, 0, 0.01, 0.01, 0, 0.1, 0.1, 0.1, 0.01, 0],
#  'reg_lambda': [0, 0.01, 0, 0.01, 0, 0.01, 0.01, 0.01, 0, 0]}

# %%
xgbr_coef_list = [np.abs(l) for l in zip(*xgbr_result_dict['importance'])]
xgbr_label_list = [item.split()[-1] for item in X.columns.values]
xgbr_label_list.append("")
plt.boxplot(xgbr_coef_list)
plt.xticks(np.arange(1, len(xgbr_label_list) + 1, 5), labels=xgbr_label_list[::5])
plt.ylabel('Feature Importance')
plt.xlabel('Feature Number')
plt.show()

# %%
def print_feature_importances(coef_list, label_list):
    feature_avg_weight_dict = dict(zip(label_list, [np.mean(np.abs(l)) for l in zip(*coef_list)]))
    feature_std_weight_dict = dict(zip(label_list, [np.std(np.abs(l)) for l in zip(*coef_list)]))
    feature_avg_weight_dict = dict(sorted(feature_avg_weight_dict.items(), key=lambda x: x[1], reverse=True))
    count = 1
    for key, value in feature_avg_weight_dict.items():
        print('Rank {:>2}: {}, has an avg. importance of {:.4f} with a std. dev. of {:.4f}.'.format(count, key, value, feature_std_weight_dict[key]))
        count += 1
print_feature_importances(xgbr_result_dict['importance'], X.columns.values)
# Out:
# Rank  1: Feature 6, has an avg. importance of 0.0419 with a std. dev. of 0.0091.
# Rank  2: Feature 79, has an avg. importance of 0.0230 with a std. dev. of 0.0045.
# Rank  3: Feature 57, has an avg. importance of 0.0207 with a std. dev. of 0.0164.
# Rank  4: Feature 1, has an avg. importance of 0.0195 with a std. dev. of 0.0058.
# Rank  5: Feature 38, has an avg. importance of 0.0194 with a std. dev. of 0.0032.
# Rank  6: Feature 124, has an avg. importance of 0.0189 with a std. dev. of 0.0050.
# Rank  7: Feature 47, has an avg. importance of 0.0185 with a std. dev. of 0.0038.
# Rank  8: Feature 58, has an avg. importance of 0.0178 with a std. dev. of 0.0046.
# Rank  9: Feature 72, has an avg. importance of 0.0177 with a std. dev. of 0.0042.
# Rank 10: Feature 120, has an avg. importance of 0.0168 with a std. dev. of 0.0033.
# Rank 11: Feature 121, has an avg. importance of 0.0157 with a std. dev. of 0.0090.
# Rank 12: Feature 149, has an avg. importance of 0.0153 with a std. dev. of 0.0040.
# Rank 13: Feature 27, has an avg. importance of 0.0152 with a std. dev. of 0.0048.
# Rank 14: Feature 44, has an avg. importance of 0.0150 with a std. dev. of 0.0071.
# Rank 15: Feature 56, has an avg. importance of 0.0141 with a std. dev. of 0.0078.
# Rank 16: Feature 78, has an avg. importance of 0.0138 with a std. dev. of 0.0046.
# Rank 17: Feature 125, has an avg. importance of 0.0137 with a std. dev. of 0.0061.
# Rank 18: Feature 145, has an avg. importance of 0.0132 with a std. dev. of 0.0035.
# Rank 19: Feature 77, has an avg. importance of 0.0130 with a std. dev. of 0.0082.
# Rank 20: Feature 51, has an avg. importance of 0.0129 with a std. dev. of 0.0078.
# Rank 21: Feature 143, has an avg. importance of 0.0128 with a std. dev. of 0.0055.
# Rank 22: Feature 84, has an avg. importance of 0.0128 with a std. dev. of 0.0071.
# Rank 23: Feature 114, has an avg. importance of 0.0128 with a std. dev. of 0.0077.
# Rank 24: Feature 88, has an avg. importance of 0.0126 with a std. dev. of 0.0070.
# Rank 25: Feature 116, has an avg. importance of 0.0125 with a std. dev. of 0.0089.
# Rank 26: Feature 7, has an avg. importance of 0.0124 with a std. dev. of 0.0057.
# Rank 27: Feature 4, has an avg. importance of 0.0121 with a std. dev. of 0.0028.
# Rank 28: Feature 142, has an avg. importance of 0.0118 with a std. dev. of 0.0023.
# Rank 29: Feature 107, has an avg. importance of 0.0115 with a std. dev. of 0.0082.
# Rank 30: Feature 24, has an avg. importance of 0.0114 with a std. dev. of 0.0044.
# Rank 31: Feature 55, has an avg. importance of 0.0110 with a std. dev. of 0.0085.
# Rank 32: Feature 146, has an avg. importance of 0.0107 with a std. dev. of 0.0026.
# Rank 33: Feature 144, has an avg. importance of 0.0103 with a std. dev. of 0.0032.
# Rank 34: Feature 147, has an avg. importance of 0.0102 with a std. dev. of 0.0041.
# Rank 35: Feature 75, has an avg. importance of 0.0102 with a std. dev. of 0.0046.
# Rank 36: Feature 148, has an avg. importance of 0.0101 with a std. dev. of 0.0013.
# Rank 37: Feature 54, has an avg. importance of 0.0100 with a std. dev. of 0.0047.
# Rank 38: Feature 94, has an avg. importance of 0.0097 with a std. dev. of 0.0041.
# Rank 39: Feature 90, has an avg. importance of 0.0095 with a std. dev. of 0.0054.
# Rank 40: Feature 85, has an avg. importance of 0.0095 with a std. dev. of 0.0096.
# Rank 41: Feature 137, has an avg. importance of 0.0094 with a std. dev. of 0.0049.
# Rank 42: Feature 108, has an avg. importance of 0.0094 with a std. dev. of 0.0045.
# Rank 43: Feature 117, has an avg. importance of 0.0092 with a std. dev. of 0.0065.
# Rank 44: Feature 13, has an avg. importance of 0.0089 with a std. dev. of 0.0078.
# Rank 45: Feature 113, has an avg. importance of 0.0088 with a std. dev. of 0.0053.
# Rank 46: Feature 10, has an avg. importance of 0.0086 with a std. dev. of 0.0048.
# Rank 47: Feature 49, has an avg. importance of 0.0085 with a std. dev. of 0.0070.
# Rank 48: Feature 5, has an avg. importance of 0.0082 with a std. dev. of 0.0033.
# Rank 49: Feature 89, has an avg. importance of 0.0081 with a std. dev. of 0.0057.
# Rank 50: Feature 74, has an avg. importance of 0.0080 with a std. dev. of 0.0057.
# Rank 51: Feature 118, has an avg. importance of 0.0079 with a std. dev. of 0.0070.
# Rank 52: Feature 141, has an avg. importance of 0.0079 with a std. dev. of 0.0018.
# Rank 53: Feature 28, has an avg. importance of 0.0077 with a std. dev. of 0.0035.
# Rank 54: Feature 87, has an avg. importance of 0.0077 with a std. dev. of 0.0047.
# Rank 55: Feature 8, has an avg. importance of 0.0077 with a std. dev. of 0.0091.
# Rank 56: Feature 33, has an avg. importance of 0.0077 with a std. dev. of 0.0041.
# Rank 57: Feature 42, has an avg. importance of 0.0077 with a std. dev. of 0.0069.
# Rank 58: Feature 16, has an avg. importance of 0.0076 with a std. dev. of 0.0093.
# Rank 59: Feature 61, has an avg. importance of 0.0075 with a std. dev. of 0.0043.
# Rank 60: Feature 43, has an avg. importance of 0.0072 with a std. dev. of 0.0052.
# Rank 61: Feature 25, has an avg. importance of 0.0071 with a std. dev. of 0.0050.
# Rank 62: Feature 109, has an avg. importance of 0.0071 with a std. dev. of 0.0073.
# Rank 63: Feature 115, has an avg. importance of 0.0068 with a std. dev. of 0.0057.
# Rank 64: Feature 50, has an avg. importance of 0.0066 with a std. dev. of 0.0088.
# Rank 65: Feature 18, has an avg. importance of 0.0065 with a std. dev. of 0.0055.
# Rank 66: Feature 83, has an avg. importance of 0.0064 with a std. dev. of 0.0048.
# Rank 67: Feature 69, has an avg. importance of 0.0062 with a std. dev. of 0.0063.
# Rank 68: Feature 73, has an avg. importance of 0.0061 with a std. dev. of 0.0062.
# Rank 69: Feature 111, has an avg. importance of 0.0061 with a std. dev. of 0.0059.
# Rank 70: Feature 130, has an avg. importance of 0.0060 with a std. dev. of 0.0057.
# Rank 71: Feature 23, has an avg. importance of 0.0060 with a std. dev. of 0.0044.
# Rank 72: Feature 9, has an avg. importance of 0.0060 with a std. dev. of 0.0053.
# Rank 73: Feature 32, has an avg. importance of 0.0059 with a std. dev. of 0.0064.
# Rank 74: Feature 98, has an avg. importance of 0.0059 with a std. dev. of 0.0102.
# Rank 75: Feature 14, has an avg. importance of 0.0057 with a std. dev. of 0.0045.
# Rank 76: Feature 59, has an avg. importance of 0.0056 with a std. dev. of 0.0052.
# Rank 77: Feature 17, has an avg. importance of 0.0055 with a std. dev. of 0.0032.
# Rank 78: Feature 3, has an avg. importance of 0.0055 with a std. dev. of 0.0039.
# Rank 79: Feature 48, has an avg. importance of 0.0055 with a std. dev. of 0.0051.
# Rank 80: Feature 110, has an avg. importance of 0.0055 with a std. dev. of 0.0076.
# Rank 81: Feature 93, has an avg. importance of 0.0051 with a std. dev. of 0.0045.
# Rank 82: Feature 26, has an avg. importance of 0.0051 with a std. dev. of 0.0101.
# Rank 83: Feature 36, has an avg. importance of 0.0050 with a std. dev. of 0.0035.
# Rank 84: Feature 92, has an avg. importance of 0.0050 with a std. dev. of 0.0074.
# Rank 85: Feature 46, has an avg. importance of 0.0047 with a std. dev. of 0.0050.
# Rank 86: Feature 66, has an avg. importance of 0.0047 with a std. dev. of 0.0050.
# Rank 87: Feature 91, has an avg. importance of 0.0047 with a std. dev. of 0.0043.
# Rank 88: Feature 127, has an avg. importance of 0.0046 with a std. dev. of 0.0050.
# Rank 89: Feature 76, has an avg. importance of 0.0045 with a std. dev. of 0.0053.
# Rank 90: Feature 53, has an avg. importance of 0.0044 with a std. dev. of 0.0048.
# Rank 91: Feature 65, has an avg. importance of 0.0043 with a std. dev. of 0.0051.
# Rank 92: Feature 30, has an avg. importance of 0.0042 with a std. dev. of 0.0053.
# Rank 93: Feature 19, has an avg. importance of 0.0039 with a std. dev. of 0.0062.
# Rank 94: Feature 11, has an avg. importance of 0.0038 with a std. dev. of 0.0048.
# Rank 95: Feature 119, has an avg. importance of 0.0037 with a std. dev. of 0.0032.
# Rank 96: Feature 123, has an avg. importance of 0.0036 with a std. dev. of 0.0047.
# Rank 97: Feature 29, has an avg. importance of 0.0035 with a std. dev. of 0.0037.
# Rank 98: Feature 21, has an avg. importance of 0.0035 with a std. dev. of 0.0055.
# Rank 99: Feature 12, has an avg. importance of 0.0031 with a std. dev. of 0.0050.
# Rank 100: Feature 39, has an avg. importance of 0.0031 with a std. dev. of 0.0032.
# Rank 101: Feature 2, has an avg. importance of 0.0031 with a std. dev. of 0.0041.
# Rank 102: Feature 22, has an avg. importance of 0.0028 with a std. dev. of 0.0050.
# Rank 103: Feature 40, has an avg. importance of 0.0027 with a std. dev. of 0.0056.
# Rank 104: Feature 82, has an avg. importance of 0.0026 with a std. dev. of 0.0037.
# Rank 105: Feature 97, has an avg. importance of 0.0026 with a std. dev. of 0.0042.
# Rank 106: Feature 71, has an avg. importance of 0.0026 with a std. dev. of 0.0048.
# Rank 107: Feature 41, has an avg. importance of 0.0023 with a std. dev. of 0.0052.
# Rank 108: Feature 126, has an avg. importance of 0.0022 with a std. dev. of 0.0035.
# Rank 109: Feature 80, has an avg. importance of 0.0021 with a std. dev. of 0.0028.
# Rank 110: Feature 122, has an avg. importance of 0.0020 with a std. dev. of 0.0042.
# Rank 111: Feature 31, has an avg. importance of 0.0019 with a std. dev. of 0.0029.
# Rank 112: Feature 81, has an avg. importance of 0.0018 with a std. dev. of 0.0035.
# Rank 113: Feature 131, has an avg. importance of 0.0018 with a std. dev. of 0.0053.
# Rank 114: Feature 45, has an avg. importance of 0.0017 with a std. dev. of 0.0029.
# Rank 115: Feature 15, has an avg. importance of 0.0017 with a std. dev. of 0.0036.
# Rank 116: Feature 150, has an avg. importance of 0.0016 with a std. dev. of 0.0034.
# Rank 117: Feature 37, has an avg. importance of 0.0016 with a std. dev. of 0.0047.
# Rank 118: Feature 112, has an avg. importance of 0.0015 with a std. dev. of 0.0023.
# Rank 119: Feature 62, has an avg. importance of 0.0014 with a std. dev. of 0.0027.
# Rank 120: Feature 68, has an avg. importance of 0.0012 with a std. dev. of 0.0036.
# Rank 121: Feature 139, has an avg. importance of 0.0012 with a std. dev. of 0.0035.
# Rank 122: Feature 95, has an avg. importance of 0.0011 with a std. dev. of 0.0034.
# Rank 123: Feature 64, has an avg. importance of 0.0010 with a std. dev. of 0.0028.
# Rank 124: Feature 101, has an avg. importance of 0.0009 with a std. dev. of 0.0020.
# Rank 125: Feature 106, has an avg. importance of 0.0009 with a std. dev. of 0.0017.
# Rank 126: Feature 102, has an avg. importance of 0.0008 with a std. dev. of 0.0023.
# Rank 127: Feature 67, has an avg. importance of 0.0007 with a std. dev. of 0.0017.
# Rank 128: Feature 129, has an avg. importance of 0.0007 with a std. dev. of 0.0014.
# Rank 129: Feature 60, has an avg. importance of 0.0007 with a std. dev. of 0.0020.
# Rank 130: Feature 86, has an avg. importance of 0.0004 with a std. dev. of 0.0012.
# Rank 131: Feature 35, has an avg. importance of 0.0004 with a std. dev. of 0.0008.
# Rank 132: Feature 70, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 133: Feature 135, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 134: Feature 20, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 135: Feature 34, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 136: Feature 52, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 137: Feature 63, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 138: Feature 96, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 139: Feature 99, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 140: Feature 100, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 141: Feature 103, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 142: Feature 104, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 143: Feature 105, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 144: Feature 128, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 145: Feature 132, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 146: Feature 133, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 147: Feature 134, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 148: Feature 136, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 149: Feature 138, has an avg. importance of 0.0000 with a std. dev. of 0.0000.
# Rank 150: Feature 140, has an avg. importance of 0.0000 with a std. dev. of 0.0000.

# %% [markdown]
# The previously printed RMSE values show that the heavily cross-validated XGBoost has a better performance on both the testing and training sets within the cross validation. The performance on the test sets is quite remarkable at .938. This value is notable because the model was built using `GridSearchCV` with internal cross-validation. These results show that the model was able to create some generalizable functionality. Before moving on to the next model, let's visualize the predictions of a model with the best average parameters on the held out test set.

# %%
plot_pred = None
xgbr = None
X_test__ = None
# Loop only exists to limit variable scope.
for i in [1]:
    test_xgbr_best_params_dict = {key: max(set(value), key=value.count) for (key, value) in xgbr_best_params_dict.items()}
    test_xgbr_best_params_dict.update(default_xgbr_params)
    print(test_xgbr_best_params_dict)
    mean_imputer   = SimpleImputer()
    X_train__      = mean_imputer.fit_transform(X_train)
    X_test__       = mean_imputer.transform(X_test)
    xgbr = XGBClassifier(**test_xgbr_best_params_dict).fit(X_train__, y_train)
    plot_pred = xgbr.predict(X_test__)
# Out:
# {'n_estimators': 25, 'learning_rate': 0.3, 'max_depth': 3, 'gamma': 0.1, 'reg_lambda': 0, 'verbosity': 1, 'objective': 'multi:softprob', 'n_jobs': 1}

# %%
xgbr.save_model('XGBC_best_params')

# %%
sorted_y_test, sorted_plot_pred = [list(tuple) for tuple in zip(*sorted(zip(y_test, plot_pred)))]
plt.scatter(np.arange(0, len(sorted_y_test)), sorted_y_test, marker='d', color='k', label='Ground Truth')
plt.scatter(np.arange(0, len(sorted_plot_pred)), sorted_plot_pred, marker='+', color='r', label='XGBoost Prediction')
plt.xlabel('Data Point Number')
plt.ylabel('Coach Tenure Classification')
plt.yticks([0,1,2,3], labels=[0,1,2,""])
plt.xlim(0, len(sorted_plot_pred) + 1)
plt.legend()
plt.show()

# %%
print('Average AUROC: {:.3f}'.format(roc_auc_score(y_test, xgbr.predict_proba(X_test__), average='macro', multi_class='ovr')))
# Out:
# Average AUROC: 0.685

# %% [markdown]
# The previous plot shows that the XGBoost model has an impressive AUROC of .674. This is better than the logistic regression model, which had an AUROC of .644 on the same held-out test set. These test results show some promise of predicitive value.

# %%
def print_predictions(mod, arr, tenure_list):
    integer_lookup_list = []
    count = 0
    probas = mod.predict_proba(arr)
    for tenure in mod.predict(arr):
        if tenure in tenure_list:
            integer_lookup_list.append((count, probas[count]))  
        count += 1
    return integer_lookup_list

# %%
df_ = pd.read_csv('master_data.csv', index_col=0)
df_.fillna(0, inplace=True)
df_ = df_[df_['Coach Tenure Class'] == -1]
print(df_.shape)
df_.head(26)
# Out:
# (21, 154)
#                Coach Name  Year  Feature 1  Feature 2  Feature 3  Feature 4  \
# 0             Aaron Glenn  2025         53          0          0          0
# 31            Ben Johnson  2025         39          0          1          0
# 69         Brian Callahan  2024         40          0          0          0
# 70           Brian Daboll  2022         47          0          0          1
# 72   Brian Schottenheimer  2025         52          0          2          1
# 133             Dan Quinn  2024         54          1          6          3
# 139          Dave Canales  2024         43          0          3          0
# 145          DeMeco Ryans  2023         39          0          0          0
# 320          Jim Harbaugh  2024         61          1          0          0
# 388       Jonathan Gannon  2023         40          0          0          0
# 394          Kellen Moore  2025         36          0          0          0
# 399       Kevin O'Connell  2022         37          0          0          0
# 411             Liam Coen  2025         40          0          3          4
# 451        Mike Macdonald  2024         37          0          0          1
# 459         Mike McDaniel  2022         39          0          0          0
# 479           Mike Vrabel  2025         50          1          3          0
# 513          Pete Carroll  2025         74          3          2          4
# 533         Raheem Morris  2024         48          1          3          1
# 593           Sean Payton  2023         60          2          5          2
# 594        Shane Steichen  2023         38          0          0          0
# 611           Todd Bowles  2022         59          1          0          3
#
#      Feature 5  Feature 6  Feature 7  Feature 8  ...  Feature 143  \
# 0            0          5          4          0  ...    -0.012856
# 31           0          4          3          0  ...    -0.097931
# 69           0          3          5          0  ...    -0.164661
# 70           0         10          8          0  ...    -0.085672
# 72           0          8         14          0  ...     0.199980
# 133          0          8          5          6  ...     1.188696
# 139          0          6          1          0  ...     0.506368
# 145          0          3          2          0  ...     1.190423
# 320         16          2          0          4  ...     0.437967
# 388          0          3          2          0  ...     0.648922
# 394          0          1          6          0  ...    -0.356003
# 399          0          3          3          0  ...     1.037633
# 411          0          0          2          0  ...     0.450331
# 451          0          4          2          0  ...     0.673891
# 459          0          6          1          0  ...    -0.687420
# 479          0          3          1          6  ...     0.225057
# 513          9          6          6         18  ...     0.033470
# 533          0          9          4          3  ...     0.206449
# 593          0          5          3         15  ...    -0.831944
# 594          0          4          3          0  ...     0.386133
# 611          0         13          5          4  ...    -0.743610
#
#      Feature 144  Feature 145  Feature 146  Feature 147  Feature 148  \
# 0      -1.263665    -1.187244    -1.102638    -1.624895     0.092283
# 31     -0.883688     0.213985    -1.099407     0.889190     0.747721
# 69     -1.308011     0.319058    -0.685212    -0.055987    -1.061439
# 70     -1.750313     0.066710    -1.404165    -0.508331     0.141678
# 72      0.415432    -0.201603    -0.065758     0.303106     0.400758
# 133    -0.407393     0.337047    -0.828606     0.628450    -0.898061
# 139    -1.477273    -0.444299    -1.201064    -0.470088    -1.654772
# 145    -1.859089     1.562923    -1.609182     1.198335     0.756328
# 320     0.316324     0.704380    -0.259284     1.062612     0.009139
# 388     0.161049    -0.061903    -0.511958     0.110017     0.196116
# 394    -0.168533     0.796527    -0.255498     0.717207     0.278595
# 399     0.823631     1.227198     0.968715     1.054194     0.313821
# 411    -0.333438     1.281241    -0.255037     1.027224    -0.550325
# 451     0.095109     1.166143     0.592572     0.499014    -0.072551
# 459    -0.837057     0.016579    -0.974018     0.179651     1.330603
# 479    -1.417657    -0.422295    -1.194970    -0.626945    -1.147747
# 513    -1.073360    -0.101123    -0.912436    -0.108760    -0.694799
# 533    -0.305420     0.277926    -0.046320     0.090644    -1.188994
# 593    -0.416945    -0.696839    -0.373030    -0.755784    -0.178588
# 594    -0.412160    -0.103977    -0.511958     0.009927     0.817166
# 611     1.280222    -0.680633     1.189288    -0.898962     1.106166
#
#      Feature 149  Feature 150  Avg 2Y Win Pct  Coach Tenure Class
# 0       0.710263          0.0        0.000000                  -1
# 31     -0.193002          0.0        0.000000                  -1
# 69     -0.129255          0.0        0.176471                  -1
# 70      0.968437          0.0        0.455882                  -1
# 72      0.017944          1.0        0.000000                  -1
# 133     0.866486          0.0        0.705882                  -1
# 139    -0.411087          0.0        0.294118                  -1
# 145     0.812410          0.0        0.588235                  -1
# 320    -0.609940          1.0        0.647059                  -1
# 388    -0.356606          1.0        0.352941                  -1
# 394    -0.534413          0.0        0.000000                  -1
# 399    -0.743645          0.0        0.588235                  -1
# 411     0.860391          0.0        0.000000                  -1
# 451    -0.378190          1.0        0.588235                  -1
# 459     0.341429          0.0        0.588235                  -1
# 479     0.697600          0.0        0.000000                  -1
# 513     0.761584          0.0        0.000000                  -1
# 533     0.252741          0.0        0.470588                  -1
# 593    -0.177692          0.0        0.529412                  -1
# 594     1.338076          0.0        0.500000                  -1
# 611    -0.705693          2.0        0.500000                  -1
#
# [21 rows x 154 columns]

# %%
X_ = df_.iloc[:,2:-2]
y_ = df_.iloc[:,-1]
X_.head(5)
# Out:
#     Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0          53          0          0          0          0          5
# 31         39          0          1          0          0          4
# 69         40          0          0          0          0          3
# 70         47          0          0          1          0         10
# 72         52          0          2          1          0          8
#
#     Feature 7  Feature 8  Feature 9  Feature 10  ...  Feature 141  \
# 0           4          0   0.000000    0.000000  ...     0.352941
# 31          3          0   1.649025    1.737787  ...     0.352941
# 69          5          0  -0.183835   -0.355235  ...     0.382353
# 70          8          0  -0.539089   -0.515554  ...     0.305147
# 72         14          0   0.143263   -0.183343  ...     0.558824
#
#     Feature 142  Feature 143  Feature 144  Feature 145  Feature 146  \
# 0     -1.060228    -0.012856    -1.263665    -1.187244    -1.102638
# 31    -0.594120    -0.097931    -0.883688     0.213985    -1.099407
# 69    -1.061871    -0.164661    -1.308011     0.319058    -0.685212
# 70    -1.745387    -0.085672    -1.750313     0.066710    -1.404165
# 72     0.722236     0.199980     0.415432    -0.201603    -0.065758
#
#     Feature 147  Feature 148  Feature 149  Feature 150
# 0     -1.624895     0.092283     0.710263          0.0
# 31     0.889190     0.747721    -0.193002          0.0
# 69    -0.055987    -1.061439    -0.129255          0.0
# 70    -0.508331     0.141678     0.968437          0.0
# 72     0.303106     0.400758     0.017944          1.0
#
# [5 rows x 150 columns]

# %%
y_.head(5)
# Out:
# 0    -1
# 31   -1
# 69   -1
# 70   -1
# 72   -1
# Name: Coach Tenure Class, dtype: int64

# %%
from xgboost import XGBClassifier

best_xgbr_param_dict = {
    "n_estimators":     25,
    "learning_rate":    .3,
    "max_depth":        3,
    "gamma":            .1,
    "reg_lambda":       0
}

default_xgbr_params = {
    'verbosity':    1,
    'objective':    'multi:softprob',
    'n_jobs':       1
}

best_xgbr_param_dict.update(default_xgbr_params)
print(best_xgbr_param_dict)

xgbr = XGBClassifier(**best_xgbr_param_dict).fit(X_train, y_train)
plot_pred = xgbr.predict(X_)
print(plot_pred)
# Out:
# {'n_estimators': 25, 'learning_rate': 0.3, 'max_depth': 3, 'gamma': 0.1, 'reg_lambda': 0, 'verbosity': 1, 'objective': 'multi:softprob', 'n_jobs': 1}
# [2 1 2 1 0 1 1 1 0 1 0 2 1 2 0 2 2 0 0 0 1]

# %%
count = 0
for index, probas in print_predictions(xgbr, X_, [0,1,2]):
    if df_.loc[X_.iloc[index].name]['Year'] >= 2022:
        print('{:<22} {:>4} {:>2} {} {}'.format(df_.loc[X_.iloc[index].name]['Coach Name'], df_.loc[X_.iloc[index].name]['Year'], df_.loc[X_.iloc[index].name]['Coach Tenure Class'], probas, plot_pred[count]))
    count += 1
# Out:
# Aaron Glenn            2025 -1 [0.21378736 0.2238265  0.56238616] 2
# Ben Johnson            2025 -1 [0.3587737  0.42382008 0.21740624] 1
# Brian Callahan         2024 -1 [0.2762632  0.27495563 0.44878113] 2
# Brian Daboll           2022 -1 [0.22138128 0.5656544  0.21296431] 1
# Brian Schottenheimer   2025 -1 [0.40409094 0.26813063 0.32777846] 0
# Dan Quinn              2024 -1 [0.2803566  0.50299597 0.21664743] 1
# Dave Canales           2024 -1 [0.20387028 0.4785477  0.31758198] 1
# DeMeco Ryans           2023 -1 [0.08888548 0.54814893 0.36296558] 1
# Jim Harbaugh           2024 -1 [0.6044022  0.12793677 0.26766104] 0
# Jonathan Gannon        2023 -1 [0.23755804 0.4133751  0.3490669 ] 1
# Kellen Moore           2025 -1 [0.6129505  0.19164956 0.19539995] 0
# Kevin O'Connell        2022 -1 [0.0715474  0.31580988 0.61264277] 2
# Liam Coen              2025 -1 [0.19858204 0.4753459  0.32607204] 1
# Mike Macdonald         2024 -1 [0.04615963 0.3556064  0.59823394] 2
# Mike McDaniel          2022 -1 [0.3590285  0.32085904 0.32011247] 0
# Mike Vrabel            2025 -1 [0.15610392 0.39848632 0.44540977] 2
# Pete Carroll           2025 -1 [0.0653903 0.2971809 0.6374288] 2
# Raheem Morris          2024 -1 [0.53803176 0.16017525 0.30179298] 0
# Sean Payton            2023 -1 [0.4572154  0.4245731  0.11821143] 0
# Shane Steichen         2023 -1 [0.5456249  0.31075817 0.14361688] 0
# Todd Bowles            2022 -1 [0.20478916 0.6237235  0.17148736] 1
